# %% [markdown]
# # Spark marine pipeline
#
# Capstone Spark job (no dashboard app needed):
#
# 1. Fetch Open-Meteo marine conditions for default ports
# 2. Write Delta silver → `/tmp/coastal_ops/marine_conditions_silver`
# 3. Sync ports, snapshots, and narrative docs into Lakebase
#
# **Next:** `notebooks/ingest_marine_embeddings.ipynb`, then Playground + MCP.
#
# Attach **Serverless** or a cluster with Spark, then run the cell below.

# %%
# %run ./spark_marine_pipeline

# %%
display(spark.read.format("delta").load("/tmp/coastal_ops/marine_conditions_silver"))
